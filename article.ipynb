# %%
img = "01_bb.png"
img_alt =  "خدا کودکان را از ترامپ و نتانیاهو محافظت می‌کند"
img_cap = "تولیدشده توسط هوش مصنوعی"
Title = "آب که سر بالا میره، قورباغه ابو عطا می‌خونه"
Target = "articles/2026/Jan/01_bb_farsi.html"
Date = "Jan 2, 2026"
Content =  "شراکت میان ترامپ و اپستین یک مسیر اجتماعیِ دارای جایگاه بالا ایجاد کرد که دامنه و مشروعیت ظاهریِ شبکهٔ شکارگرانهٔ اپستین را به‌طور چشمگیری تقویت کرد. اپستین با بهره‌گیری از املاک ترامپ، مانند مارالاگو و هتل پلازا، به صحنه‌ای معتبر دست یافت تا تحت پوشش محافل نخبگانیِ انتخاب ملکه‌های زیبایی و مد سطح بالا (مانند شام‌های مدلینگ)، زنان جوان را شناسایی و جذب کند. این همکاری به او امکان داد خود را به‌عنوان «بهترین دوست دان» معرفی کند؛ عنوانی که به‌عنوان یک روش شکار برای جلب اعتماد مدل‌های نوپا به کار می‌برد، با وعدهٔ دسترسی به بالاترین لایه‌های جامعهٔ نیویورک و پالم‌بیچ. این مبادلهٔ متقابل سرمایهٔ اجتماعی—که در آن بدن زنان به‌عنوان ارز در بازیِ ego و سلطه تلقی می‌شد—پوشش لازم و محیطی نمایشی برای اپستین فراهم کرد تا قربانیان را grooming کند و عملاً عملیات قاچاق انسان خود را در انحصاری‌ترین محافل قدرت آمریکا ادغام نماید."
ref = "https://www.nytimes.com/2025/12/18/us/jeffrey-epstein-donald-trump.html"
ref_title = "پدوفیلی (کودک‌خواهی / گرایش جنسی به کودکان):"

Content_1 =  "به‌عنوان معمار اصلی محاصره و عملیات نظامی، بنیامین نتانیاهو مسئولیت مستقیم قحطیِ گستردهٔ دست‌ساز انسان را بر عهده دارد که هم‌اکنون جان کودکان غزه را می‌گیرد. تحت مدل مشخص توزیع کمک‌های انسانیِ دولت او، دست‌کم ۱۳۰ کودک بر اثر سوءتغذیه و کم‌آبی جان باخته‌اند؛ نوزادانِ به‌شدت لاغر شده توانایی تنظیم دمای بدن خود یا مقابله با ساده‌ترین عفونت‌ها را از دست می‌دهند. دولت نتانیاهو به‌طور سیستماتیک منابع حیاتی را به سطحی مرگبار از «چکه‌ای» محدود کرده و بیش از ۴۱ هزار نوزاد و کودک خردسال را دچار سوءتغذیهٔ حاد شدید کرده است. با مهندسی فروپاشی نظام درمانی و جلوگیری از نزدیک به ۵۰٪ درخواست‌های انتقال کمک، نتانیاهو حدود ۱۳۲ هزار کودک زیر پنج سال را تا سال ۲۰۲۶ در معرض خطر فوری مرگ قرار داده است. این فاجعهٔ انسانی نتیجهٔ مستقیم تصمیم‌های آگاهانهٔ سیاستی در بالاترین سطوح دولت اسرائیل است که گرسنگیِ قابل پیشگیری را به سلاحی تبدیل کرده و جوان‌ترین و آسیب‌پذیرترین اعضای جامعه را نابود می‌کند."
ref_1 = "https://www.theguardian.com/world/2025/jul/25/israel-deflect-blame-starvation-gaza-hunger"
ref_title_1 = "نسل‌کشی:"
 
html_content = f"""
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Article Title</title>
    <link rel="stylesheet" href="../../../styles/article_style.css">
</head>
<body>

<nav>
    <a href="../../../index.html">Home</a>
    <a href="../../../navigation/news.html">News</a>
    <a href="../../../navigation/analysis.html">Analysis</a>
    <a href="../../../navigation/stories.html">Stories</a>
    <a href="../../../navigation/khabar.html">اخبار</a>
     <a href="../../../navigation/tahlil.html">تحلیل</a>
    <a href="../../../navigation/dastan.html">داستان</a>
    <a href="../../../navigation/xinwen.html">新聞</a>
    <a href="../../../navigation/fenxi.html">分析</a>
    <a href="../../../navigation/gushi.html">故事</a>
</nav>

<article class="article-container">
    <h1>{Title}</h1>
    <p class="date">Published: {Date}</p>

    <figure>
                    <img src={img} alt={img_alt}>
                    <figcaption> {img_cap} </figcaption>
    </figure>


    <p>
    <a href="{ref}" target="_blank">{ref_title}</a>
    {Content}
    </p>

    <p>
    <a href="{ref_1}" target="_blank">{ref_title_1}</a>
    {Content_1}
    </p>
    
</article>

</body>
</html>
"""

with open(Target, "w", encoding="utf-8") as f:
    f.write(html_content)

print("html created!")
# Out:
# html created!

# %%
link = "../articles/2026/Jan/01_bb_farsi.html"
img = "../articles/2026/Jan/01_bb.png"
img_alt  =  "خدا کودکان را از ترامپ و نتانیاهو محافظت می‌کند"
Summary =  "هم‌گراییِ اتحاد ترامپ–اپستین و محاصرهٔ نتانیاهو بازتاب‌دهندهٔ بحرانی عمیق در رهبریِ مدرن است؛ جایی که استثمار سیستماتیک و گرسنگیِ مهندسی‌شدهٔ کودکان، به نهایتِ سوءاستفاده از قدرت تبدیل می‌شود."
Title = "آب که سر بالا میره، قورباغه ابو عطا می‌خونهآب که سر بالا میره، قورباغه ابو عطا می‌خونه"

html_content = f"""
<!-- article 4 -->
<div class="article-box">
        <img src={img} alt="img_alt">
        <div class="article-content">
            <h2><a href={link}>{Title}</a></h2>
            <p> {Summary} </p>
        </div>
</div>
"""

print(html_content)
# Out:
# <!-- article 4 -->
# <div class="article-box">
#         <img src=../articles/2026/Jan/01_bb.png alt="img_alt">
#         <div class="article-content">
#             <h2><a href=../articles/2026/Jan/01_bb_farsi.html>آب که سر بالا میره، قورباغه ابو عطا می‌خونهآب که سر بالا میره، قورباغه ابو عطا می‌خونه</a></h2>
#             <p> هم‌گراییِ اتحاد ترامپ–اپستین و محاصرهٔ نتانیاهو بازتاب‌دهندهٔ بحرانی عمیق در رهبریِ مدرن است؛ جایی که استثمار سیستماتیک و گرسنگیِ مهندسی‌شدهٔ کودکان، به نهایتِ سوءاستفاده از قدرت تبدیل می‌شود. </p>
#         </div>
# </div>

# %%
Main_link = "articles/2025/Dec/04_khameneyi.html"
Main_img = "articles/2025/Dec/04_khameneyi.png"
Main_img_alt = "Khamenei running Middle East zoo"
Main_Summary = "Iran’s Supreme Leader said women are managers with equal rights to men, excelling in society while upholding family values."
Main_Title = "Where there's smoke, there's fire."

BS1_link = "articles/2025/Dec/04_vaccine.html"
BS1_img = "articles/2025/Dec/04_vaccine.png"
BS1_img_alt = "Glowing happy brain after vaccination"
BS1_Summary = "Vaccines help protect your brain — but if your brain is telling you vaccines are bad, that’s exactly why you might want one."
BS1_Title = "If the salt loses its savor, wherewith shall it be salted?"

BS2_link = "articles/2025/Dec/05_putin.html"
BS2_img = "articles/2025/Dec/05_putin.png"
BS2_img_alt = "Asian dictators have triumphed over European ones."
BS2_Summary = "India continues to support Russia amid the Ukraine war, buying Russian oil despite U.S. sanctions and resisting condemnation of Moscow."
BS2_Title = "What goes around comes around."

SS1_link = "articles/2026/Jan/01_bb.html"
SS1_img = "articles/2026/Jan/01_bb.png"
SS1_img_alt = "God protecting children from Trump and Netanyahu"
SS1_Summary = "The convergence of the Trump-Epstein alliance and Netanyahu’s blockade reflects a profound crisis of modern leadership, where the systematic exploitation and the engineered starvation of children represent the ultimate abuse of power."
SS1_Title = "When the cat’s away, the mice will play."

SS2_link = "articles/2025/Dec/06_kennedy.html"
SS2_img = "articles/2025/Dec/06_kennedy.png"
SS2_img_alt = "JFK made America soar; RFK Jr. made it stumble"
SS2_Summary = "A CDC committee reshaped by RFK Jr. scrapped universal newborn hepatitis B shots, a move experts call dangerous and unscientific."
SS2_Title = "You can’t inherit character."


SR1_link = "articles/2025/Dec/03_musk.html"
SR1_img = "articles/2025/Dec/03_musk.png"
SR1_img_alt = "Trump beating Musk"
SR1_Summary = ""
SR1_Title = "Even a Bare Roof Won’t Get You Home."

SR2_link = "articles/2025/Dec/03_musk.html"
SR2_img = "articles/2025/Dec/03_musk.png"
SR2_img_alt = "Trump beating Musk"
SR2_Summary = ""
SR2_Title = "Even a Bare Roof Won’t Get You Home."



html_content = f"""
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>News Page</title>
    <link rel="stylesheet" href="styles/style.css">
</head>
<body>

<!-- NAVIGATION BAR -->
<nav>
    <a href="index.html">Home</a>
    <a href="navigation/news.html">News</a>
    <a href="navigation/analysis.html">Analysis</a>
    <a href="navigation/stories.html">Stories</a>
    <a href="navigation/khabar.html">اخبار</a>
    <a href="navigation/tahlil.html">تحلیل</a>
    <a href="navigation/dastan.html">داستان</a>
    <a href="navigation/xinwen.html">新聞</a>
    <a href="navigation/fenxi.html">分析</a>
    <a href="navigation/gushi.html">故事</a>
</nav>


<!-- MAIN CONTENT -->
<div class="container">
    <!-- Main Article FIRST in HTML -->
    <div class="main-column">
        
        <div class="box large">
        <a href={Main_link}>
            <img src={Main_img} alt={Main_img_alt}>
            <div class="content">
                <h2>{Main_Title}</h2>
                <p>{Main_Summary}</p>
            </div>
        </a>
        </div>
        
        
        <div class="bottom-center">
        
            <div class="box">
            <a href={BS1_link}>       
            <img src={BS1_img} alt={BS1_img_alt}>
            <div class="content">
                <h2>{BS1_Title}</h2>
                <p>{BS1_Summary}</p>
            </div>
            </a>
            </div>
            
            <div class="box">
            <a href={BS2_link}>       
            <div class="box">
            <img src={BS2_img} alt={BS2_img_alt}>
            <div class="content">
                <h2>{BS2_Title}</h2>
                <p>{BS2_Summary}</p>
            </div>
            </div>
            </a>
            </div>
            
        </div>
    </div>

    <!-- Side Left -->
    <div class="side-left">
        <div class="box">
            <a href={SS1_link}>       
            <div class="box">
            <img src={SS1_img} alt={SS1_img_alt}>
            <div class="content">
                <h2>{SS1_Title}</h2>
                <p>{SS1_Summary}</p>
            </div>
            </div>
            </a>
        </div>
        <div class="box">
            <a href={SS2_link}>       
            <div class="box">
            <img src={SS2_img} alt={SS2_img_alt}>
            <div class="content">
                <h2>{SS2_Title}</h2>
                <p>{SS2_Summary}</p>
            </div>
            </div>
            </a>
        </div>
    </div>

    <!-- Side Right -->
    <div class="side-right">
        <div class="box">
            <a href={SR1_link}>       
            <div class="box">
            <img src={SR1_img} alt={SR1_img_alt}>
            <div class="content">
                <h2>{SR1_Title}</h2>
                <p>{SR1_Summary}</p>
            </div>
            </div>
            </a>
        </div>
        
        <div class="box">
         <a href={SR2_link}>       
            <div class="box">
            <img src={SR2_img} alt={SR2_img_alt}>
            <div class="content">
                <h2>{SR2_Title}</h2>
                <p>{SR2_Summary}</p>
            </div>
            </div>
         </a>
        </div>
    </div>
</div>

<!-- FOOTER -->
<footer>
    <span class="contact-email">Contact: </span>
    <div class="social-links">
        <a href="https://www.youtube.com/@WeyfanHsing" target="_blank">YouTube</a> |
        <a href="https://x.com/WeyfanHsing" target="_blank">Twitter</a> |
        <a href="https://www.facebook.com/profile.php?id=61584400270418" target="_blank">Facebook</a> |
        <a href="https://www.instagram.com/weyfanhsing/" target="_blank">Instagram</a> |
        <a href="https://www.tiktok.com/@weyfanhsing" target="_blank">TikTok</a> |
        <a href="https://www.linkedin.com/in/arash-abedijaberi" target="_blank">LinkedIn</a>
    </div>
</footer>


</body>
</html>
"""

with open("index.html", "w", encoding="utf-8") as f:
    f.write(html_content)

print("index.html created!")
# Out:
# index.html created!
